# %% [markdown]
# The datafiles contain pre-processed training and test data from the Ames housing dataset. Train a DT model predicting "SalesPrice".
#
# Build a pipeline for the Ames data that includes a Feature Selection step using Pearson's correlation and a DT step. Create a HP grid tuning the *k* HP of the feature selection step and the *max_depth* and *min_samples_leaf* of the DT model, choosing ranges for each of the HPs. Determine the best HP settings using Bayesian Optimisation.
#
# Replace the step that selects features based on Pearson's *r* with feature selection based on RFE. Comment on the results obtained.
#
# Some parts of the solution are already provided. Write code in the empty cells and in places indicated with "???".
#
# Hint: use "Sklearn pipeline.ipynb" and "RFE.ipynb" as examples.

# %%
# !pip install scikit-optimize
# Out:
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.12/dist-packages (0.10.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (1.5.3)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (25.7.0)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (2.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (1.6.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize) (25.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.6.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

sns.set_theme(palette="Set2")

# execution time
from timeit import default_timer as timer
from datetime import timedelta

# increase column width
pd.set_option('display.max_colwidth', 250)

# silence warnings
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Load the data

# %%
trainset = pd.read_csv("trainset-ames-housing.csv")
testset = pd.read_csv("testset-ames-housing.csv")

# separate predictors and target
ytrain = trainset["SalePrice"].copy()
Xtrain = trainset.drop("SalePrice", axis=1)
ytest = testset["SalePrice"].copy()
Xtest = testset.drop("SalePrice", axis=1)

# %% [markdown]
# # Model development

# %% [markdown]
# ## Feature Selection with Pearson's r

# %%
from skopt import BayesSearchCV

# import relevant modules
from imblearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import r_regression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %%
start = timer()

pipe = Pipeline([
    ('fsel', SelectKBest(r_regression)),
    ('dt', DecisionTreeRegressor(random_state=7))
])

hp_grid = {
    'fsel__k': [3, 21],
    'dt__max_depth': [2,25],
    'dt__min_samples_leaf': [1,50],
}

opt_grid_search = BayesSearchCV(
     pipe,
     hp_grid,
     n_iter=30,
     random_state=7,
     scoring='neg_root_mean_squared_error',
     return_train_score=True,
     cv=10
)

np.int = int
opt_grid_search.fit(Xtrain, ytrain)

print("Execution time HH:MM:SS:", timedelta(seconds=timer() - start))
# Out:
# Execution time HH:MM:SS: 0:00:43.566588

# %%
cv_results = pd.DataFrame(opt_grid_search.cv_results_)[['params', 'mean_train_score', 'mean_test_score']]
cv_results["mean_train_score"] = -cv_results["mean_train_score"]
cv_results["mean_test_score"] = -cv_results["mean_test_score"]
cv_results["diff, %"] = 100*(cv_results["mean_train_score"]-cv_results["mean_test_score"]
                                                     )/cv_results["mean_train_score"]

cv_results.sort_values('mean_test_score')
# Out:
#                                                               params  \
# 29  {'dt__max_depth': 25, 'dt__min_samples_leaf': 17, 'fsel__k': 21}
# 17  {'dt__max_depth': 25, 'dt__min_samples_leaf': 19, 'fsel__k': 21}
# 23  {'dt__max_depth': 21, 'dt__min_samples_leaf': 19, 'fsel__k': 21}
# 15  {'dt__max_depth': 25, 'dt__min_samples_leaf': 18, 'fsel__k': 21}
# 18  {'dt__max_depth': 25, 'dt__min_samples_leaf': 20, 'fsel__k': 21}
# 25  {'dt__max_depth': 23, 'dt__min_samples_leaf': 20, 'fsel__k': 21}
# 26  {'dt__max_depth': 22, 'dt__min_samples_leaf': 20, 'fsel__k': 21}
# 20  {'dt__max_depth': 25, 'dt__min_samples_leaf': 25, 'fsel__k': 21}
# 27  {'dt__max_depth': 23, 'dt__min_samples_leaf': 21, 'fsel__k': 21}
# 16   {'dt__max_depth': 25, 'dt__min_samples_leaf': 9, 'fsel__k': 21}
# 12  {'dt__max_depth': 18, 'dt__min_samples_leaf': 35, 'fsel__k': 21}
# 0   {'dt__max_depth': 25, 'dt__min_samples_leaf': 43, 'fsel__k': 21}
# 2   {'dt__max_depth': 10, 'dt__min_samples_leaf': 27, 'fsel__k': 20}
# 10  {'dt__max_depth': 14, 'dt__min_samples_leaf': 34, 'fsel__k': 20}
# 8   {'dt__max_depth': 22, 'dt__min_samples_leaf': 31, 'fsel__k': 15}
# 3   {'dt__max_depth': 10, 'dt__min_samples_leaf': 38, 'fsel__k': 17}
# 9   {'dt__max_depth': 14, 'dt__min_samples_leaf': 11, 'fsel__k': 18}
# 19   {'dt__max_depth': 24, 'dt__min_samples_leaf': 37, 'fsel__k': 9}
# 11  {'dt__max_depth': 10, 'dt__min_samples_leaf': 21, 'fsel__k': 16}
# 4    {'dt__max_depth': 13, 'dt__min_samples_leaf': 24, 'fsel__k': 6}
# 5   {'dt__max_depth': 25, 'dt__min_samples_leaf': 44, 'fsel__k': 18}
# 7   {'dt__max_depth': 21, 'dt__min_samples_leaf': 45, 'fsel__k': 13}
# 6    {'dt__max_depth': 23, 'dt__min_samples_leaf': 23, 'fsel__k': 5}
# 1   {'dt__max_depth': 15, 'dt__min_samples_leaf': 49, 'fsel__k': 15}
# 28   {'dt__max_depth': 25, 'dt__min_samples_leaf': 50, 'fsel__k': 3}
# 22   {'dt__max_depth': 10, 'dt__min_samples_leaf': 48, 'fsel__k': 5}
# 13   {'dt__max_depth': 10, 'dt__min_samples_leaf': 1, 'fsel__k': 10}
# 24   {'dt__max_depth': 2, 'dt__min_samples_leaf': 50, 'fsel__k': 21}
# 14    {'dt__max_depth': 2, 'dt__min_samples_leaf': 50, 'fsel__k': 3}
# 21     {'dt__max_depth': 2, 'dt__min_samples_leaf': 1, 'fsel__k': 3}
#
#     mean_train_score  mean_test_score     diff, %
# 29      32423.069608     38306.583111  -18.146072
# 17      33912.597352     38879.629763  -14.646570
# 23      33912.597352     38879.629763  -14.646570
# 15      33062.633695     39125.920111  -18.338788
# 18      34332.083434     39266.006288  -14.371172
# 25      34332.083434     39266.006288  -14.371172
# 26      34332.083434     39266.006288  -14.371172
# 20      35480.635347     39361.439135  -10.937808
# 27      34534.446797     39572.633485  -14.588873
# 16      28454.538357     40012.756667  -40.619947
# 12      37950.610981     40797.873680   -7.502548
# 0       40421.534650     42867.093239   -6.050138
# 2       38245.082137     42988.286092  -12.402128
# 10      39092.769422     43083.094047  -10.207321
# 8       38776.224259     43132.328084  -11.233956
# 3       39913.540720     43236.426033   -8.325208
# 9       31943.757627     43266.896006  -35.447108
# 19      39826.279096     43346.299840   -8.838437
# 11      36704.067926     43562.529585  -18.685835
# 4       39861.047116     44507.036628  -11.655463
# 5       42108.973873     44736.723802   -6.240356
# 7       42477.390454     45169.193457   -6.337025
# 6       40570.013357     45392.250972  -11.886212
# 1       43350.182316     45880.465906   -5.836846
# 28      44480.975367     46196.443394   -3.856633
# 22      44329.538519     46292.768529   -4.428717
# 13      11132.856073     49709.624738 -346.512776
# 24      49545.273040     50905.647636   -2.745720
# 14      50912.827082     52694.236583   -3.498940
# 21      50912.827082     52694.236583   -3.498940

# %% [markdown]
# # Feature selection using RFE

# %%
from imblearn.pipeline import Pipeline
from sklearn.feature_selection import RFE

start = timer()

pipe = Pipeline([
    ('fsel', RFE(DecisionTreeRegressor(random_state=7, max_depth=10), step=1)),
    ('dt', DecisionTreeRegressor(random_state=7))
])

hp_grid = {
    'fsel__n_features_to_select': [3, 21],
    'dt__max_depth': [2, 25],
    'dt__min_samples_split': [2, 50],
}

opt_grid_search = BayesSearchCV(
     pipe,
     hp_grid,
     n_iter=30,
     random_state=7,
     scoring='neg_root_mean_squared_error',
     return_train_score=True,
     cv=10
)

np.int = int
opt_grid_search.fit(Xtrain, ytrain)

print("Execution time HH:MM:SS:", timedelta(seconds=timer() - start))
# Out:
# Execution time HH:MM:SS: 0:01:13.098465

# %%
cv_results = pd.DataFrame(opt_grid_search.cv_results_)[['params', 'mean_train_score', 'mean_test_score']]
cv_results["mean_train_score"] = -cv_results["mean_train_score"]
cv_results["mean_test_score"] = -cv_results["mean_test_score"]
cv_results["diff, %"] = 100*(cv_results["mean_train_score"]-cv_results["mean_test_score"]
                                                     )/cv_results["mean_train_score"]

cv_results.sort_values('mean_test_score')
# Out:
#                                                                                   params  \
# 16  {'dt__max_depth': 11, 'dt__min_samples_split': 29, 'fsel__n_features_to_select': 21}
# 13  {'dt__max_depth': 10, 'dt__min_samples_split': 28, 'fsel__n_features_to_select': 21}
# 2   {'dt__max_depth': 10, 'dt__min_samples_split': 28, 'fsel__n_features_to_select': 20}
# 18  {'dt__max_depth': 11, 'dt__min_samples_split': 30, 'fsel__n_features_to_select': 21}
# 25  {'dt__max_depth': 23, 'dt__min_samples_split': 27, 'fsel__n_features_to_select': 21}
# 21  {'dt__max_depth': 14, 'dt__min_samples_split': 29, 'fsel__n_features_to_select': 21}
# 24  {'dt__max_depth': 12, 'dt__min_samples_split': 28, 'fsel__n_features_to_select': 21}
# 19  {'dt__max_depth': 10, 'dt__min_samples_split': 30, 'fsel__n_features_to_select': 20}
# 10  {'dt__max_depth': 25, 'dt__min_samples_split': 30, 'fsel__n_features_to_select': 21}
# 26  {'dt__max_depth': 10, 'dt__min_samples_split': 31, 'fsel__n_features_to_select': 21}
# 29  {'dt__max_depth': 23, 'dt__min_samples_split': 31, 'fsel__n_features_to_select': 21}
# 28  {'dt__max_depth': 21, 'dt__min_samples_split': 33, 'fsel__n_features_to_select': 21}
# 8   {'dt__max_depth': 22, 'dt__min_samples_split': 32, 'fsel__n_features_to_select': 15}
# 17  {'dt__max_depth': 11, 'dt__min_samples_split': 26, 'fsel__n_features_to_select': 21}
# 6    {'dt__max_depth': 23, 'dt__min_samples_split': 23, 'fsel__n_features_to_select': 5}
# 4    {'dt__max_depth': 13, 'dt__min_samples_split': 25, 'fsel__n_features_to_select': 6}
# 3   {'dt__max_depth': 10, 'dt__min_samples_split': 39, 'fsel__n_features_to_select': 17}
# 7   {'dt__max_depth': 21, 'dt__min_samples_split': 45, 'fsel__n_features_to_select': 13}
# 15  {'dt__max_depth': 18, 'dt__min_samples_split': 23, 'fsel__n_features_to_select': 21}
# 0   {'dt__max_depth': 25, 'dt__min_samples_split': 43, 'fsel__n_features_to_select': 21}
# 27  {'dt__max_depth': 12, 'dt__min_samples_split': 24, 'fsel__n_features_to_select': 21}
# 5   {'dt__max_depth': 25, 'dt__min_samples_split': 44, 'fsel__n_features_to_select': 18}
# 1   {'dt__max_depth': 15, 'dt__min_samples_split': 49, 'fsel__n_features_to_select': 15}
# 22   {'dt__max_depth': 24, 'dt__min_samples_split': 31, 'fsel__n_features_to_select': 3}
# 20   {'dt__max_depth': 11, 'dt__min_samples_split': 30, 'fsel__n_features_to_select': 3}
# 9   {'dt__max_depth': 14, 'dt__min_samples_split': 11, 'fsel__n_features_to_select': 18}
# 23   {'dt__max_depth': 16, 'dt__min_samples_split': 28, 'fsel__n_features_to_select': 3}
# 14   {'dt__max_depth': 25, 'dt__min_samples_split': 2, 'fsel__n_features_to_select': 21}
# 12    {'dt__max_depth': 10, 'dt__min_samples_split': 2, 'fsel__n_features_to_select': 3}
# 11   {'dt__max_depth': 2, 'dt__min_samples_split': 26, 'fsel__n_features_to_select': 21}
#
#     mean_train_score  mean_test_score       diff, %
# 16      27416.298781     40474.524497    -47.629426
# 13      27318.979253     40491.689826    -48.218165
# 2       27318.979253     40510.703754    -48.287765
# 18      27593.357481     40621.162170    -47.213554
# 25      26550.719357     40687.820367    -53.245642
# 21      27317.091395     40698.864694    -48.986816
# 24      27096.300419     40722.807278    -50.289178
# 19      27725.630275     40755.164953    -46.994548
# 10      27496.995327     40807.569098    -48.407375
# 26      27933.077555     40826.468144    -46.158146
# 29      27714.395532     40853.252081    -47.408057
# 28      28003.153439     40864.014479    -45.926474
# 8       27846.321925     40872.693949    -46.779507
# 17      26360.948098     41008.953815    -55.567067
# 6       26887.050109     41113.777645    -52.912936
# 4       26662.577638     41142.326845    -54.307387
# 3       30483.913732     41477.888825    -36.064841
# 7       31581.897341     41632.766290    -31.824779
# 15      25261.240103     41653.484094    -64.890892
# 0       31454.220053     41669.291470    -32.475997
# 27      25670.531302     41811.767303    -62.878465
# 5       31500.756973     41840.680048    -32.824364
# 1       32166.871519     41844.156846    -30.084633
# 22      31328.456138     41884.023894    -33.693227
# 20      31172.850191     42153.763752    -35.225889
# 9       18759.528903     42170.869905   -124.797062
# 23      30592.960425     42312.387092    -38.307593
# 14        151.963035     45770.689491 -30019.620574
# 12      13194.986679     47072.789821   -256.747536
# 11      49545.273040     50905.647636     -2.745720
