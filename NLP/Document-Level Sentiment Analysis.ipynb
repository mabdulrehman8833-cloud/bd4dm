# %% [markdown]
# The notebook shows an example how text files, labelled for sentiment (positive or negative), can be converted to a tabular format and then used to train a machine learning model capable of classifying new texts by sentiment.
#
# As an example, we will use a corpus of movie reviews first used in Pang and Lee (2004), for details see [here](http://www.cs.cornell.edu/people/pabo/movie-review-data/).

# %%
# setting logging to print only error messages of sklearnex
import logging
logging.basicConfig()
logging.getLogger("SKLEARNEX").setLevel(logging.ERROR)

import pandas as pd
import matplotlib.pyplot as plt

# execution time
from timeit import default_timer as timer
from datetime import timedelta

# %% [markdown]
# # Load the data
#
# If the data has not been downloaded before, download it, and save to a folder called "datasets", alongside this notebook.

# %%
import os
import urllib
import tarfile

url = "https://www.cs.cornell.edu/people/pabo/movie-review-data/review_polarity.tar.gz"
    
def download_data(url):
    """Download the data and extract the mo
    """
    
    # if the "datasets" folder does not exist, create it
    if not os.path.exists("datasets"):
        os.makedirs("datasets")
    
    # if the archived file does not exist, download it
    if not os.path.exists("datasets/review_polarity.tar.gz"):
        urllib.request.urlretrieve(url, "datasets/review_polarity.tar.gz")
    
    # if the unpacked file does not exist, unpack it
    if not os.path.exists("datasets/txt_sentoken"):
        infile = tarfile.open("datasets/review_polarity.tar.gz")
        infile.extractall(path="datasets")
        infile.close()

download_data(url)

# %% [markdown]
# The code above will produce a folder inside "datasets", called "txt_sentoken". That folder will contain two subfolders - "pos" (containing 1000 files manually labelled as positive) and "neg" (containing 1000 files manually labelled as "negative"). Each file is a separate movie review, after minimal normalization (inserting spaces around punctuation symbols, lower-casing all words, etc).
#
# We will use Scikit-learn's `load_files` function to load the data and then store it in a Pandas dataframe:

# %%
from sklearn.datasets import load_files

# loading all files. 
movie = load_files("./datasets/txt_sentoken/", shuffle=True)

# %%
len(movie.data)
# Out:
# 2000

# %%
# target names ("classes") are automatically generated from subfolder names
movie.target_names
# Out:
# ['neg', 'pos']

# %%
# First file seems to be about a Schwarzenegger movie. 
print(movie.data[0])
# Out:
# b"arnold schwarzenegger has been an icon for action enthusiasts , since the late 80's , but lately his films have been very sloppy and the one-liners are getting worse . \nit's hard seeing arnold as mr . freeze in batman and robin , especially when he says tons of ice jokes , but hey he got 15 million , what's it matter to him ? \nonce again arnold has signed to do another expensive blockbuster , that can't compare with the likes of the terminator series , true lies and even eraser . \nin this so called dark thriller , the devil ( gabriel byrne ) has come upon earth , to impregnate a woman ( robin tunney ) which happens every 1000 years , and basically destroy the world , but apparently god has chosen one man , and that one man is jericho cane ( arnold himself ) . \nwith the help of a trusty sidekick ( kevin pollack ) , they will stop at nothing to let the devil take over the world ! \nparts of this are actually so absurd , that they would fit right in with dogma . \nyes , the film is that weak , but it's better than the other blockbuster right now ( sleepy hollow ) , but it makes the world is not enough look like a 4 star film . \nanyway , this definitely doesn't seem like an arnold movie . \nit just wasn't the type of film you can see him doing . \nsure he gave us a few chuckles with his well known one-liners , but he seemed confused as to where his character and the film was going . \nit's understandable , especially when the ending had to be changed according to some sources . \naside form that , he still walked through it , much like he has in the past few films . \ni'm sorry to say this arnold but maybe these are the end of your action days . \nspeaking of action , where was it in this film ? \nthere was hardly any explosions or fights . \nthe devil made a few places explode , but arnold wasn't kicking some devil butt . \nthe ending was changed to make it more spiritual , which undoubtedly ruined the film . \ni was at least hoping for a cool ending if nothing else occurred , but once again i was let down . \ni also don't know why the film took so long and cost so much . \nthere was really no super affects at all , unless you consider an invisible devil , who was in it for 5 minutes tops , worth the overpriced budget . \nthe budget should have gone into a better script , where at least audiences could be somewhat entertained instead of facing boredom . \nit's pitiful to see how scripts like these get bought and made into a movie . \ndo they even read these things anymore ? \nit sure doesn't seem like it . \nthankfully gabriel's performance gave some light to this poor film . \nwhen he walks down the street searching for robin tunney , you can't help but feel that he looked like a devil . \nthe guy is creepy looking anyway ! \nwhen it's all over , you're just glad it's the end of the movie . \ndon't bother to see this , if you're expecting a solid action flick , because it's neither solid nor does it have action . \nit's just another movie that we are suckered in to seeing , due to a strategic marketing campaign . \nsave your money and see the world is not enough for an entertaining experience . \n"

# %%
movie.target[0]
# Out:
# 0

# %%
df = pd.DataFrame({"text": movie.data, "label": movie.target})
df["text"] = df["text"].astype("str")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    2000 non-null   object
#  1   label   2000 non-null   int32
# dtypes: int32(1), object(1)
# memory usage: 23.6+ KB

# %%
# keep the first 512 tokens in each document
def f(r):
    tokens = r["text"].split(" ")[:512]
    r["text"] = ' '.join(tokens)
    return r

df = df.apply(f, axis=1)

# %% [markdown]
# # Train-test split

# %%
from sklearn.model_selection import train_test_split

docs_train, docs_test, ytrain, ytest = train_test_split(df["text"], df["label"], 
                                                          test_size=0.2, random_state=7)

# %%
print(f"{len(docs_train)} train and {len(docs_test)} test instances")
# Out:
# 1600 train and 400 test instances

# %% [markdown]
# # Data transformation
#
# ## Create Bag-of-Words representations
#
# `CountVectorizer` is a convenient facility to create bag-of-words representations of documents into a numpy array. Setting the arguments of the constructor class, we can configure the basic linguistic preprocessing steps that should be applied to it: supplying a custom tokenizer, stopword list, ngram range, etc.

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer(
    strip_accents="unicode", # convert accented chars to non-accented versions
    lowercase=True,
    tokenizer=None,        # None - use the default tokenizer
    preprocessor=None,     # None - use the default preprocessor
    stop_words="english",
    ngram_range=(1,1),     # min and max range of ngrams
    analyzer="word",       # split the document into words, rather than e.g. characters
    max_df=1.0,            # ignore words with df greater than the value (int represents count, 
                           # float represents proportion of documents)
    min_df=1               # ignore words the df lower than the value (int represents count, 
                           # float represents proportion)
)

# %% [markdown]
# We first create an instance of `CountVectorizer` and then call its `fit_transform` method. It first "fits" on the data, i.e., extracts individual features from each document, as specified by the arguments to the constructor method (e.g., extract bigrams), and then "transforms" the data, i.e. creates numpy arrays where rows are documents, columns are features extracted from the documents, and values in the cells are counts of each feature in each document:

# %%
# fit and tranform using training text 
docs_train_counts = count_vectorizer.fit_transform(docs_train)

# %%
docs_train_counts.shape
# Out:
# (1600, 30876)

# %% [markdown]
# Thus, there 1600 rows, one for each document, and 36304 columns, one for each feature.
#
# Let's check the datatype of the data:

# %%
type(docs_train_counts)
# Out:
# scipy.sparse._csr.csr_matrix

# %% [markdown]
# Note the data is stored in a special data structure called "sparse matrix", specifically Compressed Sparse Row. Because there are many zeros in each row (in the first row, there are 139 non-zero values, out of the total of 36034), the sparse matrix stores the data more efficiently and thus is able to represent relatively large text collections, without running into memory errors.
#
# We can, however, convert a sparse matrix to a normal, "dense", numpy array, if needed:

# %%
docs_train_counts[0, :].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %% [markdown]
# The fitted `count_vectorizer` stores also the vocabulary of the text collection on which it was fitted.

# %%
count_vectorizer.vocabulary_
# Out:
# {'plot': 20651,
#  'realization': 22128,
#  'failing': 9963,
#  'classes': 5153,
#  'roommates': 23368,
#  'try': 28421,
#  'roomie': 23364,
#  'kill': 15228,
#  'school': 23968,
#  'charter': 4768,
#  'automatically': 2175,
#  'grants': 11921,
#  'grades': 11876,
#  'student': 26491,
#  'succeeds': 26638,
#  'suicide': 26700,
#  'critique': 6550,
#  'despite': 7503,
#  'film': 10356,
#  'interesting': 14321,
#  'premise': 21094,
#  'dark': 6944,
#  'subject': 26564,
#  'matter': 17053,
#  'movie': 18101,
#  'sucks': 26661,
#  'unfunny': 28893,
#  'boring': 3457,
#  'presents': 21134,
#  'tom': 27917,
#  'everett': 9546,
#  'scott': 24045,
#  'worst': 30533,
#  'acting': 719,
#  'performances': 20143,
#  'add': 762,
#  'completely': 5672,
#  'unsuccessful': 29110,
#  'romance': 23325,
#  'element': 8907,
#  'lame': 15545,
#  'corny': 6217,
#  'jokes': 14874,
#  'long': 16272,
#  'wait': 29810,
#  'setup': 24429,
#  'ending': 9150,
#  'takes': 27173,
#  'blackness': 3101,
#  'black': 3091,
#  'comedy': 5535,
#  'gonna': 11771,
#  'create': 6457,
#  'don': 8227,
#  'chicken': 4889,
#  'end': 9137,
#  'bad': 2334,
#  'things': 27629,
#  '10': 4,
#  'perfect': 20131,
#  'example': 9604,
#  've': 29391,
#  'got': 11836,
#  'trite': 28336,
#  'mtv': 18132,
#  'creation': 6461,
#  'worthy': 30539,
#  'barely': 2487,
#  'laughed': 15671,
#  'gags': 11210,
#  'bong': 3384,
#  'contrived': 6084,
#  'repetitive': 22671,
#  'horrified': 13212,
#  'gratuitous': 11943,
#  'nudity': 18857,
#  'tossed': 28012,
#  'make': 16674,
#  'college': 5460,
#  'slap': 25127,
#  'free': 10979,
#  'shots': 24739,
#  'kids': 15215,
#  'worth': 30534,
#  'rental': 22636,
#  'fellas': 10206,
#  'skip': 25083,
#  'altogether': 1224,
#  'little': 16156,
#  'known': 15367,
#  'facts': 9947,
#  'stars': 26079,
#  'auditions': 2116,
#  'thing': 27625,
#  'feature': 10162,
#  'role': 23308,
#  'director': 7792,
#  'hanks': 12425,
#  'opposed': 19217,
#  'hiring': 12970,
#  'fact': 9939,
#  'passed': 19864,
#  '15': 45,
#  'years': 30689,
#  'ago': 1008,
#  'wasn': 29931,
#  'wife': 30256,
#  'rita': 23183,
#  'wilson': 30296,
#  'saw': 23847,
#  'audition': 2114,
#  'tape': 27244,
#  'decided': 7095,
#  'cute': 6776,
#  'risk': 23175,
#  'actor': 733,
#  'played': 20596,
#  'cooper': 6153,
#  'mark': 16883,
#  'paul': 19939,
#  'gosselaar': 11833,
#  'best': 2916,
#  'having': 12594,
#  'character': 4726,
#  'zack': 30777,
#  'morris': 18002,
#  'tv': 28513,
#  'saved': 23834,
#  'bell': 2810,
#  'parents': 19788,
#  'dutch': 8641,
#  'named': 18331,
#  'hans': 12435,
#  'paula': 19940,
#  'guessed': 12163,
#  'alan': 1086,
#  'cohn': 5397,
#  'shot': 24737,
#  'directing': 7786,
#  'enduring': 9163,
#  'mariah': 16862,
#  'carey': 4379,
#  'debut': 7060,
#  'glitter': 11649,
#  'reminded': 22578,
#  'bit': 3067,
#  'chris': 4989,
#  'rock': 23270,
#  'bigger': 2986,
#  'blacker': 3093,
#  'response': 22843,
#  'women': 30435,
#  'saying': 23855,
#  'raise': 21922,
#  'child': 4897,
#  'man': 16725,
#  'says': 23858,
#  'drive': 8486,
#  'car': 4351,
#  'feet': 10191,
#  'mean': 17191,
#  'say': 23853,
#  'certainly': 4644,
#  'sure': 26846,
#  'plenty': 20639,
#  'pop': 20819,
#  'star': 26054,
#  'vehicles': 29404,
#  'beatles': 2670,
#  'hard': 12464,
#  'day': 6995,
#  'night': 18638,
#  'spice': 25752,
#  'girls': 11575,
#  'world': 30507,
#  'vapidly': 29359,
#  'pointless': 20723,
#  'laughable': 15669,
#  'complete': 5670,
#  'tripe': 28323,
#  'ludicrous': 16439,
#  'start': 26083,
#  'story': 26322,
#  'gruesomely': 12125,
#  'predictable': 21053,
#  'offensive': 19057,
#  'inexplicably': 14002,
#  'set': 24414,
#  '80s': 328,
#  'period': 20157,
#  'piece': 20403,
#  'really': 22134,
#  'shows': 24774,
#  'sign': 24862,
#  'chicks': 4891,
#  'leg': 15811,
#  'warmers': 29898,
#  'worse': 30526,
#  'speaking': 25690,
#  'late': 15654,
#  '90s': 341,
#  'hip': 12958,
#  'hop': 13164,
#  'slang': 25126,
#  '1983': 159,
#  'meant': 17206,
#  'partially': 19829,
#  'autobiographical': 2170,
#  'plays': 20608,
#  'billie': 3009,
#  'frank': 10936,
#  'young': 30743,
#  'singer': 24958,
#  'new': 18555,
#  'york': 30737,
#  'struggles': 26472,
#  'overcome': 19454,
#  'rough': 23431,
#  'childhood': 4901,
#  'abandonment': 500,
#  'alcoholic': 1108,
#  'mother': 18034,
#  'influential': 14041,
#  'club': 5295,
#  'dj': 8130,
#  'julian': 14975,
#  'dice': 7665,
#  'lucky': 16435,
#  'max': 17080,
#  'beesley': 2734,
#  'playing': 20605,
#  'mix': 17758,
#  'puff': 21602,
#  'daddy': 6830,
#  'robert': 23243,
#  'niro': 18679,
#  'hears': 12675,
#  'sing': 24954,
#  'track': 28072,
#  'decides': 7097,
#  'predictably': 21054,
#  'rapid': 22004,
#  'succession': 26643,
#  'fall': 9996,
#  'starts': 26091,
#  'hitting': 13009,
#  'big': 2982,
#  'gets': 11489,
#  'jealous': 14723,
#  'like': 16036,
#  'ass': 1906,
#  'suddenly': 26665,
#  'roller': 23314,
#  'coaster': 5334,
#  'superstardom': 26806,
#  'meantime': 17207,
#  'emotional': 9064,
#  'hunt': 13415,
#  'missing': 17719,
#  'mom': 17852,
#  'won': 30437,
#  'away': 2239,
#  'honestly': 13121,
#  'just': 15017,
#  'think': 27630,
#  'unicorns': 28909,
#  'rainbows': 21911,
#  'll': 16180,
#  'figure': 10339,
#  'screams': 24082,
#  'camp': 4224,
#  'fun': 11122,
#  'filmmakers': 10368,
#  'thought': 27665,
#  'making': 16682,
#  'bulk': 3927,
#  'weepy': 30054,
#  'dramatic': 8396,
#  'better': 2937,
#  'mistake': 17731,
#  'brief': 3723,
#  'attempts': 2064,
#  'comic': 5546,
#  'relief': 22526,
#  'scene': 23913,
#  'effeminate': 8824,
#  'russian': 23567,
#  'sounding': 25607,
#  'wacky': 29782,
#  'filming': 10366,
#  'music': 18238,
#  'video': 29535,
#  'lead': 15739,
#  'balloons': 2401,
#  'instead': 14233,
#  'audience': 2108,
#  'screening': 24088,
#  'tended': 27443,
#  'laugh': 15668,
#  'loudest': 16353,
#  'scenes': 23915,
#  'brings': 3749,
#  'good': 11776,
#  'said': 23661,
#  'primarily': 21214,
#  'seen': 24241,
#  'wide': 30237,
#  'eyed': 9894,
#  'deer': 7165,
#  'headlights': 12641,
#  'look': 16289,
#  'frozen': 11080,
#  'face': 9922,
#  'actually': 743,
#  'looks': 16296,
#  'scared': 23887,
#  'love': 16373,
#  'wonder': 30439,
#  'writing': 30592,
#  'isn': 14587,
#  'dialogue': 7643,
#  'hackneyed': 12292,
#  'watered': 29958,
#  'virginal': 29627,
#  'target': 27262,
#  'probably': 21264,
#  'impossible': 13765,
#  'heard': 12671,
#  'priest': 21203,
#  'rabbi': 21836,
#  'dosage': 8297,
#  'featherweight': 10159,
#  'charm': 4758,
#  'sprinkled': 25888,
#  'keeping': 15124,
#  'faith': 9982,
#  'fluffy': 10666,
#  'thoroughly': 27659,
#  'glazed': 11622,
#  'sense': 24320,
#  'innocuous': 14147,
#  'innocence': 14143,
#  'cheer': 4823,
#  'regarding': 22399,
#  'moral': 17952,
#  'topics': 27963,
#  'religion': 22529,
#  'romantic': 23332,
#  'triangle': 28279,
#  'causes': 4548,
#  'collide': 5464,
#  'head': 12628,
#  'youngsters': 30748,
#  'brian': 3708,
#  'finn': 10420,
#  'jacob': 14639,
#  'schramm': 23982,
#  'anna': 1458,
#  'reilly': 22456,
#  'inseparable': 14180,
#  'trio': 28321,
#  'friendship': 11040,
#  'progressed': 21352,
#  'compassion': 5637,
#  'shower': 24763,
#  'support': 26825,
#  'feel': 10185,
#  'excluded': 9651,
#  'tragedy': 28095,
#  'soon': 25553,
#  'struck': 26465,
#  'forced': 10779,
#  'adults': 870,
#  'edward': 8807,
#  'norton': 18775,
#  'ben': 2838,
#  'stiller': 26234,
#  'hold': 13046,
#  'similar': 24910,
#  'contrastive': 6075,
#  'jobs': 14838,
#  'likable': 16035,
#  'kind': 15253,
#  'hearted': 12683,
#  'father': 10110,
#  'catholic': 4528,
#  'spry': 25903,
#  'outgoing': 19375,
#  'acts': 738,
#  'jewish': 14794,
#  'basketball': 2565,
#  'court': 6332,
#  'refer': 22347,
#  'god': 11709,
#  'squad': 25921,
#  'relationship': 22497,
#  'field': 10311,
#  'abides': 524,
#  'principle': 21227,
#  'celibacy': 4597,
#  'reached': 22090,
#  'point': 20717,
#  'finding': 10393,
#  'bride': 3716,
#  'practically': 20987,
#  'mandatory': 16739,
#  'changes': 4701,
#  'jenna': 14753,
#  'elfman': 8919,
#  'returns': 22942,
#  'visit': 29656,
#  'chums': 5029,
#  'workaholic': 30490,
#  'devotes': 7616,
#  'endless': 9152,
#  'hours': 13267,
#  'week': 30045,
#  'business': 4049,
#  'does': 8166,
#  'spare': 25664,
#  'time': 27796,
#  'reminisce': 22584,
#  'ecstatic': 8764,
#  'seeing': 24232,
#  'elementary': 8908,
#  'sweetheart': 26992,
#  'oddball': 19023,
#  'ingredients': 14084,
#  'cocktail': 5362,
#  'bound': 3503,
#  'awkward': 2250,
#  'central': 4623,
#  'characters': 4734,
#  'predicting': 21057,
#  'outcome': 19362,
#  'entirely': 9293,
#  'difficult': 7703,
#  'open': 19181,
#  'entertaining': 9275,
#  'refreshingly': 22380,
#  'relaxed': 22505,
#  'travels': 28224,
#  'en': 9104,
#  'route': 23449,
#  'emerged': 9034,
#  'finest': 10401,
#  'flexibly': 10586,
#  'versatile': 29471,
#  'actors': 734,
#  'hollywood': 13071,
#  'success': 26639,
#  'sparked': 25668,
#  'critically': 6539,
#  'lauded': 15667,
#  '1996': 173,
#  'thriller': 27696,
#  'primal': 21212,
#  'fear': 10143,
#  'shockingly': 24691,
#  'bitter': 3081,
#  'roles': 23309,
#  'american': 1291,
#  'history': 12990,
#  'recently': 22197,
#  'david': 6983,
#  'fincher': 10391,
#  'vicious': 29517,
#  'fight': 10330,
#  'quaint': 21741,
#  'peculiar': 20008,
#  'choice': 4946,
#  'slips': 25218,
#  'chair': 4669,
#  'incisive': 13859,
#  'resourceful': 22826,
#  'approach': 1640,
#  'helps': 12785,
#  'additional': 774,
#  'craft': 6405,
#  'surprisingly': 26875,
#  'perceptive': 20120,
#  'screenplay': 24090,
#  'stuart': 26482,
#  'blumberg': 3260,
#  'weighing': 30058,
#  'aspect': 1897,
#  'unanimously': 28643,
#  'impressive': 13785,
#  'directorial': 7794,
#  'addition': 773,
#  'pushes': 21709,
#  'right': 23122,
#  'buttons': 4088,
#  'sheepish': 24591,
#  'generating': 11403,
#  'screen': 24085,
#  'presence': 21127,
#  'zipper': 30844,
#  'guy': 12257,
#  'mary': 16952,
#  'firm': 10447,
#  'funny': 11151,
#  'boasting': 3295,
#  'fully': 11117,
#  'ripened': 23160,
#  'maturity': 17064,
#  'perky': 20171,
#  'repetition': 22667,
#  'grow': 12107,
#  'tiresome': 27848,
#  'occasionally': 18994,
#  'case': 4454,
#  'dharma': 7630,
#  'greg': 12000,
#  'perfectly': 20136,
#  'rambunctious': 21946,
#  'remaining': 22553,
#  'cast': 4474,
#  'members': 17301,
#  'offer': 19059,
#  'fine': 10396,
#  'anne': 1463,
#  'altman': 1222,
#  'cookie': 6140,
#  'fortune': 10872,
#  'rare': 22020,
#  'depend': 7391,
#  'sentimentality': 24344,
#  'uplifting': 29183,
#  'viewers': 29555,
#  'sunny': 26759,
#  'delightful': 7273,
#  'dreamy': 8441,
#  'filled': 10351,
#  'lovely': 16379,
#  'skillful': 25068,
#  'direction': 7787,
#  'topped': 27967,
#  'understated': 28786,
#  'clever': 5208,
#  'extraordinary': 9865,
#  'script': 24108,
#  'ensemble': 9250,
#  'slowly': 25242,
#  'introduces': 14425,
#  'residing': 22792,
#  'southern': 25623,
#  'town': 28053,
#  'called': 4184,
#  'holly': 13070,
#  'springs': 25884,
#  'meet': 17260,
#  'willie': 30284,
#  'charles': 4752,
#  'dutton': 8645,
#  'honest': 13120,
#  'slight': 25198,
#  'drinking': 8478,
#  'habit': 12279,
#  'care': 4364,
#  'elderly': 8884,
#  'lady': 15516,
#  'nicknamed': 18612,
#  'losing': 16339,
#  'grip': 12047,
#  'sanity': 23758,
#  'loneliness': 16267,
#  'despair': 7492,
#  'want': 29876,
#  'dead': 7012,
#  'husband': 13441,
#  'cut': 6773,
#  'camille': 4221,
#  'glenn': 11636,
#  'close': 5268,
#  'obsessively': 18971,
#  'play': 20590,
#  'sister': 24992,
#  'cora': 6188,
#  'julianne': 14977,
#  'moore': 17943,
#  'briefly': 3727,
#  'acquainted': 701,
#  'emma': 9053,
#  'liv': 16160,
#  'tyler': 28555,
#  'apparent': 1585,
#  'relative': 22499,
#  'teen': 27373,
#  'outcast': 19360,
#  'hope': 13165,
#  'real': 22115,
#  'place': 20533,
#  'live': 16161,
#  'fleetingly': 10575,
#  'lover': 16382,
#  'jason': 14705,
#  'donnell': 8245,
#  'ambitious': 1275,
#  'far': 10053,
#  'excitable': 9640,
#  'cop': 6162,
#  'quarter': 21757,
#  'hour': 13265,
#  'picture': 20396,
#  'motion': 18044,
#  'stare': 26060,
#  'hopefully': 13168,
#  'exclaims': 9648,
#  'come': 5526,
#  'puts': 21717,
#  'pillow': 20443,
#  'shoots': 24714,
#  'niece': 18625,
#  'stops': 26308,
#  'fruit': 11081,
#  'salad': 23682,
#  'bowl': 3526,
#  'comes': 5539,
#  'upstairs': 29211,
#  'finds': 10395,
#  'flips': 10612,
#  'convinced': 6129,
#  'disgrace': 7906,
#  'family': 10020,
#  'eats': 8736,
#  'note': 18795,
#  'convinces': 6130,
#  'slightly': 25201,
#  'slow': 25239,
#  'sweet': 26989,
#  'murder': 18205,
#  'makes': 16678,
#  'stages': 25989,
#  'scattering': 23907,
#  'jewelry': 14792,
#  'floor': 10634,
#  'breaking': 3654,
#  'cabinets': 4123,
#  'windows': 30314,
#  'doors': 8269,
#  'throwing': 27716,
#  'gun': 12216,
#  'yard': 30666,
#  'reasonable': 22152,
#  'suspect': 26905,
#  'immediately': 13670,
#  'taken': 27169,
#  'custody': 6767,
#  'jail': 14654,
#  'cell': 4599,
#  'know': 15361,
#  'didn': 7681,
#  'stays': 26125,
#  'scrabble': 24056,
#  'sheriff': 24632,
#  'faithful': 9983,
#  'unperturbed': 29023,
#  'continues': 6048,
#  'subtle': 26620,
#  'manipulations': 16784,
#  'trying': 28422,
#  'cover': 6354,
#  'easter': 8723,
#  'begins': 2761,
#  'aptly': 1660,
#  'described': 7457,
#  'critic': 6537,
#  'renshaw': 22634,
#  'spin': 25775,
#  'fargo': 10062,
#  'funnier': 11149,
#  'enjoyable': 9214,
#  'coen': 5377,
#  'brothers': 3820,
#  'darker': 6946,
#  'somewhat': 25533,
#  'practical': 20986,
#  'magic': 16613,
#  'misguided': 17690,
#  'ways': 29987,
#  'talented': 27181,
#  'high': 12903,
#  'profile': 21334,
#  'involved': 14500,
#  'embarrassing': 9007,
#  'clap': 5133,
#  'trap': 28195,
#  'sandra': 23745,
#  'bullock': 3938,
#  'nicole': 18618,
#  'kidman': 15203,
#  'sally': 23695,
#  'gillian': 11551,
#  'owens': 19576,
#  'sisters': 24994,
#  'line': 16089,
#  'witches': 30384,
#  'spanning': 25661,
#  '200': 182,
#  'die': 7682,
#  'children': 4905,
#  'zany': 30797,
#  'aunts': 2131,
#  'stockard': 26265,
#  'channing': 4706,
#  'dianne': 7653,
#  'wiest': 30253,
#  'switch': 27030,
#  'present': 21128,
#  'stronger': 26462,
#  'rebellious': 22166,
#  'sibling': 24822,
#  'leaves': 15774,
#  'home': 13085,
#  'meets': 17263,
#  'abusive': 596,
#  'goran': 11810,
#  'visjnic': 29663,
#  'hometown': 13096,
#  'falls': 10001,
#  'caring': 4388,
#  'devastated': 7571,
#  'hit': 12992,
#  'truck': 28385,
#  'killed': 15230,
#  'minutes': 17632,
#  'calls': 4191,
#  'spat': 25678,
#  'accidentally': 624,
#  'desperation': 7497,
#  'bury': 4038,
#  'body': 3318,
#  'backyard': 2330,
#  'house': 13268,
#  'wildly': 30271,
#  'convoluted': 6133,
#  'subplots': 26590,
#  'involving': 14503,
#  'rising': 23174,
#  'exorcism': 9724,
#  'mention': 17336,
#  'spattering': 25682,
#  'light': 16020,
#  'whimsy': 30168,
#  'pretty': 21175,
#  'idea': 13529,
#  'messy': 17406,
#  'reflected': 22363,
#  'liked': 16039,
#  'enjoyed': 9216,
#  'humor': 13384,
#  'astoundingly': 1998,
#  'flat': 10542,
#  'occasional': 18993,
#  'moments': 17857,
#  'touching': 28025,
#  'charming': 4761,
#  'way': 29981,
#  'bird': 3047,
#  'brained': 3581,
#  'evil': 9563,
#  'spirit': 25788,
#  'taking': 27175,
#  'handled': 12402,
#  'terribly': 27502,
#  'getting': 11490,
#  'reason': 22151,
#  'standing': 26037,
#  'attempt': 2061,
#  'flesh': 10578,
#  'actual': 739,
#  'people': 20098,
#  'goes': 11733,
#  'aidan': 1029,
#  'quinn': 21802,
#  'handsome': 12409,
#  'police': 20751,
#  'investigator': 14478,
#  'misfortune': 17687,
#  'opposite': 19220,
#  '70': 307,
#  'minute': 17631,
#  'develop': 7576,
#  'service': 24404,
#  'moving': 18116,
#  'rip': 23158,
#  'movies': 18113,
#  'woody': 30467,
#  'allen': 1173,
#  'bananas': 2416,
#  'martin': 16937,
#  'scorsese': 24039,
#  'films': 10372,
#  'woo': 30454,
#  'falling': 10000,
#  'def': 7166,
#  'jam': 14666,
#  'player': 20597,
#  'awful': 2245,
#  'booty': 3441,
#  'ok': 19093,
#  'embarassing': 8999,
#  'genre': 11429,
#  'showing': 24769,
#  'african': 962,
#  'americans': 1296,
#  'sexual': 24459,
#  'buffoons': 3901,
#  'version': 29475,
#  'wild': 30264,
#  'woman': 30428,
#  'jada': 14646,
#  'pinkett': 20465,
#  'smith': 25313,
#  'blind': 3174,
#  'date': 6974,
#  'straight': 26340,
#  'laced': 15490,
#  'tim': 27795,
#  'tommy': 27933,
#  'davidson': 6986,
#  'mayhem': 17095,
#  'follows': 10732,
#  'unknown': 28972,
#  'read': 22102,
#  'antics': 1519,
#  'entire': 9292,
#  'include': 13867,
#  'destroying': 7515,
#  'bathroom': 2590,
#  'mirror': 17649,
#  'stealing': 26137,
#  'violently': 29617,
#  'questioning': 21778,
#  'accusing': 673,
#  'belittling': 2808,
#  'previous': 21188,
#  'girlfriends': 11571,
#  'causing': 4549,
#  'riot': 23152,
#  'elegant': 8905,
#  'restaurant': 22854,
#  'various': 29373,
#  'infuriating': 14062,
#  'normal': 18760,
#  'person': 20209,
#  'wouldn': 30541,
#  'tolerate': 27906,
#  'sake': 23677,
#  'chuckles': 5022,
#  'swiped': 27022,
#  'directly': 7790,
#  'running': 23546,
#  'thugs': 27724,
#  'subway': 26634,
#  'closing': 5280,
#  'taunt': 27297,
#  'joke': 14872,
#  'stolen': 26279,
#  'chuckle': 5021,
#  'provided': 21504,
#  'billy': 3019,
#  'dee': 7149,
#  'williams': 30282,
#  'cameo': 4211,
#  'seemingly': 24239,
#  'released': 22510,
#  'months': 17918,
#  'importantly': 13755,
#  'thinks': 27632,
#  'reconsider': 22246,
#  'careers': 4369,
#  'serve': 24400,
#  'textbook': 27546,
#  'difference': 7694,
#  'television': 27404,
#  'consider': 5938,
#  'moment': 17853,
#  'producer': 21306,
#  'book': 3404,
#  'features': 10164,
#  'fatal': 10101,
#  'bus': 4040,
#  'accident': 622,
#  'lawyer': 15716,
#  'bereaved': 2876,
#  'lots': 16344,
#  'hot': 13245,
#  'sensationalism': 24318,
#  'interrupted': 14367,
#  'breaks': 3657,
#  'sell': 24278,
#  'beer': 2732,
#  'toothpaste': 27957,
#  'flight': 10594,
#  'writer': 30587,
#  'atom': 2036,
#  'egoyan': 8848,
#  'delivers': 7288,
#  'tremendous': 28259,
#  'power': 20975,
#  'notable': 18790,
#  'trait': 28115,
#  'subtlety': 26622,
#  'based': 2545,
#  'respected': 22830,
#  'author': 2156,
#  'russell': 23565,
#  'banks': 2450,
#  'represents': 22705,
#  'rethinking': 22907,
#  'structure': 26468,
#  'merely': 17363,
#  'literal': 16147,
#  'adaptation': 756,
#  'novel': 18827,
#  'told': 27902,
#  'linear': 16091,
#  'form': 10836,
#  'narrators': 18364,
#  'happens': 12448,
#  'overlapping': 19495,
#  'sequences': 24366,
#  'narrator': 18363,
#  'record': 22250,
#  'applauding': 1611,
#  'press': 21146,
#  'notes': 18799,
#  'describes': 7458,
#  'parable': 19740,
#  'lost': 16342,
#  'asks': 1892,
#  'absence': 561,
#  'picking': 20388,
#  'flashback': 10532,
#  'sitter': 25005,
#  'burnell': 4014,
#  'grace': 11866,
#  'sarah': 23774,
#  'polley': 20774,
#  'reads': 22110,
#  'parts': 19851,
#  'pied': 20406,
#  'piper': 20481,
#  'old': 19097,
#  'illustrated': 13617,
#  'charges': 4742,
#  'periodically': 20160,
#  'readings': 22108,
#  'voice': 29703,
#  'poem': 20708,
#  'sweetly': 26995,
#  'appropriate': 1646,
#  'rest': 22851,
#  'harm': 12493,
#  'seriously': 24387,
#  'injured': 14127,
#  'small': 25270,
#  'canadian': 4242,
#  'occurs': 19012,
#  'physical': 20364,
#  'damage': 6863,
#  'inflicted': 14036,
#  'mainly': 16657,
#  'bear': 2648,
#  'scars': 23898,
#  'loss': 16340,
#  'ian': 13507,
#  'holm': 13074,
#  'arguably': 1729,
#  'performance': 20142,
#  'distinguished': 8051,
#  'career': 4368,
#  'mitchell': 17754,
#  'stephens': 26181,
#  'intense': 14295,
#  'quiet': 21793,
#  'misery': 17681,
#  'outsider': 19413,
#  'snow': 25417,
#  'encrusted': 9133,
#  'community': 5618,
#  'british': 3761,
#  'columbian': 5504,
#  'wilderness': 30267,
#  'mission': 17720,
#  'singular': 24970,
#  'sue': 26667,
#  'behalf': 2767,
#  'crass': 6436,
#  'approaches': 1643,
#  'job': 14834,
#  'dedication': 7146,
#  'religious': 22531,
#  'zealot': 30803,
#  'unfolds': 28876,
#  'believably': 2797,
#  'fascination': 10086,
#  'interviews': 14390,
#  ...}

# %% [markdown]
# The vocabulary is just a dictionary, where keys are original words and values are their indices in the produced matrix. The vocabulary will be used internally by the fitted vectorizer, when we transform the test data, deriving a document-by-feature matrix, which has the same columns in the same order as the training data.
#
# Let's apply the fitted vectorizer also to the test data. Note we call the `transform` method, not `fit` or `fit_transform`, because the vectorizer has been fitted already:

# %%
docs_test_counts = count_vectorizer.transform(docs_test)

# %%
docs_test_counts.shape
# Out:
# (400, 30876)

# %% [markdown]
# It has 400 rows (one per document), but the same number of columns as the training data, 36034.

# %% [markdown]
# ## TF-IDF weighting
#
# Further, we can transform the observed counts into TF-IDF weights in order to reflect the importance of every word in the document. This is achieved with `TfidfTransformer`:

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer()

# %% [markdown]
# First the transformer needs to be "fitted" on the training data and then the fitted transformer should be used to transform both the training and the test data:

# %%
# fit and transform the training set with "fit_transform()"
docs_train_tfidf = tfidf_transformer.fit_transform(docs_train_counts)

# %%
# transform test
docs_test_tfidf = tfidf_transformer.transform(docs_test_counts)

# %% [markdown]
# ## Standardize features
#
# Fit a scaler on the training set and use it to transform both the training and test sets. We'll use a `MaxAbsScaler` as it is capable of dealing with sparse matrices.

# %%
from sklearn.preprocessing import MaxAbsScaler 

scaler = MaxAbsScaler()

Xtrain = scaler.fit_transform(docs_train_tfidf)
Xtest = scaler.transform(docs_test_tfidf)

# %%
Xtrain
# Out:
# <1600x30876 sparse matrix of type '<class 'numpy.float64'>'
# 	with 272436 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Train models

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ## Baseline
#
# Classifying everything as "pos"
#
# *pos*:
# * precision: 800/1600 = 0.5
# * recall: 800/800 = 1.0
# * f-score: 2/(1/p + 1/r) = 0.66
#
# *neg*:
# * precision: 0/0 = 0.0
# * recall: 0/800 = 0.0
# * f-score: 2/(1/p + 1/r) = 0.0
#
# *Macro-averaged*:
# * precision: 0.25
# * recall: 0.5
# * **f-score: 0.33**

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import precision_recall_fscore_support

dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(Xtrain, ytrain)
yhat = dummy_clf.predict(Xtrain)

p, r, f, s = precision_recall_fscore_support(ytrain, yhat, average="macro", zero_division=0.0)
print(f"Precision: {p:.3f}")
print(f"Recall: {r:.3f}")
print(f"F score: {f:.3f}")
# Out:
# Precision: 0.254
# Recall: 0.500
# F score: 0.337

# %% [markdown]
# ## Decision Trees

# %%
start = timer()

from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier(random_state=7)

# specify the hyperparameters and their values
# 3 x 3 = 9 combinations in the grid
param_grid = {
    'max_depth': [5, 15, 30],
    'min_samples_split': [5, 10, 20],
}

# we'll use 5-fold cross-validation
grid_search = GridSearchCV(dtree, param_grid, cv=5,
                           scoring='f1_macro', 
                           return_train_score=True)
grid_search.fit(Xtrain, ytrain)

print("Execution time HH:MM:SS:", timedelta(seconds=timer() - start))
# Out:
# Execution time HH:MM:SS: 0:00:27.796058

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)[['params', 'mean_train_score', 'mean_test_score']]
cv_results["diff, %"] = 100*(cv_results["mean_train_score"]-cv_results["mean_test_score"]
                                                     )/cv_results["mean_train_score"]

pd.set_option('display.max_colwidth', 100)
cv_results.sort_values('mean_test_score', ascending=False)
# Out:
#                                        params  mean_train_score  \
# 3   {'max_depth': 15, 'min_samples_split': 5}          0.892681
# 5  {'max_depth': 15, 'min_samples_split': 20}          0.868265
# 4  {'max_depth': 15, 'min_samples_split': 10}          0.884752
# 2   {'max_depth': 5, 'min_samples_split': 20}          0.719397
# 6   {'max_depth': 30, 'min_samples_split': 5}          0.967804
# 1   {'max_depth': 5, 'min_samples_split': 10}          0.719295
# 0    {'max_depth': 5, 'min_samples_split': 5}          0.720827
# 7  {'max_depth': 30, 'min_samples_split': 10}          0.948580
# 8  {'max_depth': 30, 'min_samples_split': 20}          0.920929
#
#    mean_test_score    diff, %
# 3         0.637214  28.617944
# 5         0.633583  27.028854
# 4         0.628786  28.930807
# 2         0.623278  13.361100
# 6         0.622156  35.714700
# 1         0.621816  13.551957
# 0         0.621730  13.747715
# 7         0.613267  35.348904
# 8         0.610743  33.681797

# %% [markdown]
# ## Random Forest

# %%
start = timer()

from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=7)

# specify the hyperparameters and their values
# 4 x 3 x 3 = 36 combinations in the grid
param_grid = {
    'n_estimators': [100, 200, 500, 1000],
    'max_depth': [5, 15, 30],
    'min_samples_split': [5, 10, 20]
}

# we'll use 5-fold cross-validation
grid_search = GridSearchCV(rf, param_grid, cv=5,
                           scoring='f1_macro', 
                           return_train_score=True)
grid_search.fit(Xtrain, ytrain)

print("Execution time HH:MM:SS:", timedelta(seconds=timer() - start))
# Out:
# Execution time HH:MM:SS: 0:12:58.464324

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)[['params', 'mean_train_score', 'mean_test_score']]
cv_results["diff, %"] = 100*(cv_results["mean_train_score"]-cv_results["mean_test_score"]
                                                     )/cv_results["mean_train_score"]

pd.set_option('display.max_colwidth', 100)
cv_results.sort_values('mean_test_score', ascending=False)
# Out:
#                                                               params  \
# 33   {'max_depth': 30, 'min_samples_split': 20, 'n_estimators': 200}
# 29   {'max_depth': 30, 'min_samples_split': 10, 'n_estimators': 200}
# 30   {'max_depth': 30, 'min_samples_split': 10, 'n_estimators': 500}
# 34   {'max_depth': 30, 'min_samples_split': 20, 'n_estimators': 500}
# 19  {'max_depth': 15, 'min_samples_split': 10, 'n_estimators': 1000}
# 13    {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 200}
# 22   {'max_depth': 15, 'min_samples_split': 20, 'n_estimators': 500}
# 18   {'max_depth': 15, 'min_samples_split': 10, 'n_estimators': 500}
# 23  {'max_depth': 15, 'min_samples_split': 20, 'n_estimators': 1000}
# 28   {'max_depth': 30, 'min_samples_split': 10, 'n_estimators': 100}
# 17   {'max_depth': 15, 'min_samples_split': 10, 'n_estimators': 200}
# 14    {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 500}
# 31  {'max_depth': 30, 'min_samples_split': 10, 'n_estimators': 1000}
# 35  {'max_depth': 30, 'min_samples_split': 20, 'n_estimators': 1000}
# 32   {'max_depth': 30, 'min_samples_split': 20, 'n_estimators': 100}
# 21   {'max_depth': 15, 'min_samples_split': 20, 'n_estimators': 200}
# 25    {'max_depth': 30, 'min_samples_split': 5, 'n_estimators': 200}
# 20   {'max_depth': 15, 'min_samples_split': 20, 'n_estimators': 100}
# 15   {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 1000}
# 24    {'max_depth': 30, 'min_samples_split': 5, 'n_estimators': 100}
# 26    {'max_depth': 30, 'min_samples_split': 5, 'n_estimators': 500}
# 12    {'max_depth': 15, 'min_samples_split': 5, 'n_estimators': 100}
# 16   {'max_depth': 15, 'min_samples_split': 10, 'n_estimators': 100}
# 27   {'max_depth': 30, 'min_samples_split': 5, 'n_estimators': 1000}
# 6     {'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 500}
# 10    {'max_depth': 5, 'min_samples_split': 20, 'n_estimators': 500}
# 3     {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 1000}
# 2      {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 500}
# 7    {'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 1000}
# 9     {'max_depth': 5, 'min_samples_split': 20, 'n_estimators': 200}
# 11   {'max_depth': 5, 'min_samples_split': 20, 'n_estimators': 1000}
# 1      {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 200}
# 5     {'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 200}
# 4     {'max_depth': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 8     {'max_depth': 5, 'min_samples_split': 20, 'n_estimators': 100}
# 0      {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 100}
#
#     mean_train_score  mean_test_score    diff, %
# 33          0.988750         0.745372  24.614707
# 29          0.992812         0.744368  25.024211
# 30          0.992343         0.743949  25.031043
# 34          0.987812         0.738974  25.190844
# 19          0.976874         0.737725  24.481070
# 13          0.977343         0.737088  24.582451
# 22          0.971715         0.736548  24.201245
# 18          0.976093         0.735838  24.613906
# 23          0.972810         0.735541  24.390083
# 28          0.992499         0.734554  25.989464
# 17          0.975624         0.734444  24.720541
# 14          0.976874         0.733738  24.889188
# 31          0.992656         0.733388  26.118542
# 35          0.988593         0.733368  25.817060
# 32          0.989062         0.733167  25.872479
# 21          0.969527         0.732760  24.420878
# 25          0.994530         0.731523  26.445346
# 20          0.967184         0.731219  24.397167
# 15          0.978281         0.730910  25.286234
# 24          0.993593         0.730448  26.484196
# 26          0.993905         0.729943  26.558120
# 12          0.973905         0.729387  25.106894
# 16          0.972498         0.728198  25.120933
# 27          0.995155         0.722859  27.362171
# 6           0.927806         0.722312  22.148374
# 10          0.915766         0.722306  21.125533
# 3           0.935465         0.719325  23.105087
# 2           0.929215         0.717925  22.738530
# 7           0.933434         0.716285  23.263482
# 9           0.913409         0.714695  21.755153
# 11          0.924370         0.713810  22.778752
# 1           0.924517         0.709443  23.263432
# 5           0.921390         0.708227  23.134924
# 4           0.904313         0.704952  22.045606
# 8           0.890668         0.704353  20.918580
# 0           0.908058         0.703187  22.561471

# %% [markdown]
# Let's view the most important features:

# %%
# put them into a separate variable for convenience
feature_importances = grid_search.best_estimator_.feature_importances_

# the order of the features in `feature_importances` is the same as in count_vectorizer.get_feature_names(),
# so we can "zip" the two and print the first 50 in the descending order:
for k, v in sorted(zip(feature_importances, count_vectorizer.get_feature_names_out()), reverse=True)[:50]:
    print(f"{v}: {k:.5f}")
# Out:
# bad: 0.01448
# worst: 0.00798
# supposed: 0.00534
# boring: 0.00504
# plot: 0.00499
# life: 0.00493
# movie: 0.00453
# script: 0.00418
# reason: 0.00391
# dull: 0.00365
# mess: 0.00352
# unfortunately: 0.00341
# wasted: 0.00339
# joke: 0.00327
# stupid: 0.00323
# make: 0.00306
# just: 0.00294
# talent: 0.00291
# different: 0.00263
# lame: 0.00255
# poor: 0.00253
# tries: 0.00242
# minute: 0.00242
# better: 0.00240
# awful: 0.00240
# minutes: 0.00237
# thing: 0.00235
# big: 0.00233
# ridiculous: 0.00233
# american: 0.00231
# attempt: 0.00221
# clich: 0.00218
# wouldn: 0.00216
# problem: 0.00210
# looks: 0.00202
# waste: 0.00200
# given: 0.00197
# true: 0.00192
# hilarious: 0.00188
# look: 0.00179
# annoying: 0.00179
# video: 0.00178
# brilliant: 0.00176
# don: 0.00176
# like: 0.00171
# seen: 0.00168
# terrific: 0.00168
# day: 0.00165
# fails: 0.00165
# acting: 0.00159

# %%
from joblib import dump

# create a folder where all trained models will be kept
if not os.path.exists("models"):
    os.makedirs("models")
    
dump(grid_search.best_estimator_, 'models/rf-clf.joblib')
# Out:
# ['models/rf-clf.joblib']

# %% [markdown]
# ## Linear SVM

# %%
start = timer()

from sklearn.svm import LinearSVC

lsvm = LinearSVC(random_state=7, max_iter=10000)

# specify the hyperparameters and their values
# 7 combinations in the grid
param_grid = {
    'C': [0.0001, 0.001, 0.01, 0.1, 1, 5, 10]
}

# we'll use 5-fold cross-validation
grid_search = GridSearchCV(lsvm, param_grid, cv=5,
                           scoring='f1_macro', 
                           return_train_score=True) 
grid_search.fit(Xtrain, ytrain)

print("Execution time HH:MM:SS:", timedelta(seconds=timer() - start))
# Out:
# Execution time HH:MM:SS: 0:00:08.112876

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)[['params', 'mean_train_score', 'mean_test_score']]
cv_results["diff, %"] = 100*(cv_results["mean_train_score"]-cv_results["mean_test_score"]
                                                     )/cv_results["mean_train_score"]

cv_results.sort_values('mean_test_score', ascending=False)
# Out:
#           params  mean_train_score  mean_test_score    diff, %
# 2    {'C': 0.01}          1.000000         0.809963  19.003667
# 3     {'C': 0.1}          1.000000         0.806842  19.315795
# 5       {'C': 5}          1.000000         0.806828  19.317191
# 6      {'C': 10}          1.000000         0.806828  19.317191
# 4       {'C': 1}          1.000000         0.806201  19.379862
# 1   {'C': 0.001}          0.989054         0.788382  20.289249
# 0  {'C': 0.0001}          0.902476         0.634466  29.697170

# %% [markdown]
# Save the best model to disk:

# %%
dump(grid_search.best_estimator_, 'models/svm-linear-clf.joblib')
# Out:
# ['models/svm-linear-clf.joblib']

# %% [markdown]
# # Evaluate on test

# %%
from joblib import load
from sklearn.metrics import precision_recall_fscore_support

lsvm = load("models/svm-linear-clf.joblib")

yhat = lsvm.predict(Xtest)

# micro-averaged precision, recall and f-score
p, r, f, s = precision_recall_fscore_support(ytest, yhat, average="macro")
print(f"Precision: {p}")
print(f"Recall: {r}")
print(f"F score: {f}")
# Out:
# Precision: 0.811541261831237
# Recall: 0.8117525876796301
# F score: 0.8116417929189872

# %% [markdown]
# The accuracy scores on the test set turn out to be very similar to the one achieved during cross-validation.
#
# Plot a confusion matrix:

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(ytest, yhat, labels=lsvm.classes_,
                                        xticks_rotation="vertical", normalize="true",
                                        cmap=plt.cm.Blues)

# %% [markdown]
# # Classify previously unseen reviews
#
# Some reviews from the Rotten Tomatoes website:

# %%
new_reviews = [
               """Never let the audience off the hook, Hitchcock once said. 
               Ho achieves this in spades and with more than one hook.""",
    
               """The smartest mainstream film about class made in many 
               years, Bong Joon-ho's Parasite lays bare the lie that hard 
               work can bring anyone closer to their dreams.""",
    
               """[A] funny, inventive, scary film."""
            ]

# preprocess and transform
new_reviews_counts = count_vectorizer.transform(new_reviews)
new_reviews_tfidf = tfidf_transformer.transform(new_reviews_counts)
new_scaled = scaler.transform(new_reviews_tfidf)

# predict labels
predictions = lsvm.predict(new_scaled)

# print results
for review, category in zip(new_reviews, predictions):
    print(f'{review} => {movie.target_names[category]}\n')
# Out:
# Never let the audience off the hook, Hitchcock once said.
#                Ho achieves this in spades and with more than one hook. => neg
#
# The smartest mainstream film about class made in many
#                years, Bong Joon-ho's Parasite lays bare the lie that hard
#                work can bring anyone closer to their dreams. => pos
#
# [A] funny, inventive, scary film. => pos

# %% [markdown]
# # Citing this notebook
#
# If you use this notebook in your work, please cite it as follows:
#
# Pekar, V. (2024). Big Data for Decision Making. Lecture examples and exercises. (Version 1.0.0). URL: https://github.com/vpekar/bd4dm
